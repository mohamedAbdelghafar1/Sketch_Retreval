# %%
import os

data_dir = "C:/Users/20127/Desktop/sketch_retrieval/dataset_mine/dataset_mine/Updated categories/"

total_num_images = 0
for dirpath, dirname, filename in os.walk(data_dir):
    print(f"There are {len(dirname)} directories and {len(filename)} files in {dirpath} .")
    total_num_images += len(filename)   
print(total_num_images)
# Out:
# There are 12 directories and 0 files in C:/Users/20127/Desktop/sketch_retrieval/dataset_mine/dataset_mine/Updated categories/ .
# There are 0 directories and 248 files in C:/Users/20127/Desktop/sketch_retrieval/dataset_mine/dataset_mine/Updated categories/1-2_Distorted 3D Rectangles .
# There are 0 directories and 861 files in C:/Users/20127/Desktop/sketch_retrieval/dataset_mine/dataset_mine/Updated categories/1-3_Conjoined 3D Rectangles .
# There are 0 directories and 45 files in C:/Users/20127/Desktop/sketch_retrieval/dataset_mine/dataset_mine/Updated categories/2-1_Cube .
# There are 0 directories and 103 files in C:/Users/20127/Desktop/sketch_retrieval/dataset_mine/dataset_mine/Updated categories/2-2_Distorted Cube .
# There are 0 directories and 234 files in C:/Users/20127/Desktop/sketch_retrieval/dataset_mine/dataset_mine/Updated categories/2-3_Conjoined Cube Form .
# ...

# %%
for dirpath, dirname, filename in os.walk(data_dir):
  if len(filename) == 0:
    continue
  print(f"{dirpath.split('/')[-1]}: {len(filename)}")
# Out:
# 1-2_Distorted 3D Rectangles: 248
# 1-3_Conjoined 3D Rectangles: 861
# 2-1_Cube: 45
# 2-2_Distorted Cube: 103
# 2-3_Conjoined Cube Form: 234
# 3-1_Cylindrical Form: 123
# 3-2_Distorted Cylindrical Form: 190
# 3-3_Conjoined Cylindrical Form: 597
# 3-4 Cylindrical Segment: 56
# 4-1_Prism  Form: 138
# 4-2_Distorted Prism  Form: 237
# 4-3_Conjoined Prism Form: 509
